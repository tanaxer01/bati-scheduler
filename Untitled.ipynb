# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re
import evalys

#schedule_names = ['FCFS', 'EASY', 'DQN']
schedule_names = ['FCFS', 'DQN']

pd.DataFrame.append = pd.DataFrame._append

BASE_DIR = Path("./expe-out/")

# %% [markdown]
# # Simulations

# %%
from analysis.visual import logs_to_df

file_types = [ 
    "SimulationMonitor",
#    "JobMonitor",
    "SchedulerMonitor",
    "ConsumedEnergyMonitor",
    "HostStateSwitchMonitor"
]

df = logs_to_df(BASE_DIR, file_types)

df["SchedulerMonitor"].sort_index().T
# Out:
# schedule                        DQN           EASY       EASY+DQN  \
# makespan              259388.000000  259389.000000  259325.000000
# max_slowdown            1309.000000    1309.000000    1311.000000
# max_stretch             2516.323398    2516.323398    2520.170987
# max_waiting_time        1308.000000    1308.000000    1310.000000
# max_turnaround_time     1996.000000    1996.000000    1867.000000
# mean_slowdown             22.871277      21.362231      28.667514
# mean_pp_slowdown          22.837688      21.328633      28.634142
# mean_stretch              16.632175      18.231660      16.838645
# mean_waiting_time        119.863673     127.015102     118.836735
# mean_turnaround_time     244.053061     257.402449     233.982041
# nb_jobs                 2450.000000    2450.000000    2450.000000
# nb_jobs_finished        2450.000000    2450.000000    2450.000000
# nb_jobs_killed           467.000000    1245.000000     136.000000
# nb_jobs_rejected           0.000000       0.000000       0.000000
# nb_jobs_success         1983.000000    1205.000000    2314.000000
#
# schedule                       FCFS
# makespan              259389.000000
# max_slowdown            1309.000000
# max_stretch             2516.323398
# max_waiting_time        1308.000000
# max_turnaround_time     1996.000000
# mean_slowdown             21.375417
# mean_pp_slowdown          21.341810
# mean_stretch              18.240954
# mean_waiting_time        127.044082
# mean_turnaround_time     257.444898
# nb_jobs                 2450.000000
# nb_jobs_finished        2450.000000
# nb_jobs_killed          1249.000000
# nb_jobs_rejected           0.000000
# nb_jobs_success         1201.000000

# %%
df["SimulationMonitor"].T
# Out:
# schedule                       EASY      EASY+DQN          FCFS           DQN
# makespan               2.593150e+05  2.593250e+05  2.593150e+05  2.593150e+05
# max_slowdown           1.309000e+03  1.311000e+03  1.309000e+03  1.309000e+03
# max_stretch            2.516323e+03  2.520171e+03  2.516323e+03  2.516323e+03
# max_waiting_time       1.308000e+03  1.310000e+03  1.308000e+03  1.308000e+03
# max_turnaround_time    1.862000e+03  1.867000e+03  1.862000e+03  1.862000e+03
# mean_slowdown          2.450773e+01  2.866751e+01  2.450773e+01  2.450464e+01
# mean_pp_slowdown       2.447549e+01  2.863414e+01  2.447549e+01  2.447241e+01
# mean_stretch           1.626520e+01  1.683864e+01  1.626520e+01  1.625815e+01
# mean_waiting_time      1.150122e+02  1.188367e+02  1.150122e+02  1.150090e+02
# mean_turnaround_time   2.304763e+02  2.339820e+02  2.304763e+02  2.304722e+02
# nb_jobs                2.450000e+03  2.450000e+03  2.450000e+03  2.450000e+03
# nb_jobs_finished       2.450000e+03  2.450000e+03  2.450000e+03  2.450000e+03
# nb_jobs_killed         1.360000e+02  1.360000e+02  1.360000e+02  1.360000e+02
# nb_jobs_rejected       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# nb_jobs_success        2.314000e+03  2.314000e+03  2.314000e+03  2.314000e+03
# time_idle              3.555084e+06  3.556229e+06  3.555084e+06  3.555085e+06
# time_computing         5.939560e+05  5.929710e+05  5.939560e+05  5.939550e+05
# time_switching_off     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# time_switching_on      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# time_sleeping          0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# consumed_joules        4.505846e+08  4.505062e+08  4.505846e+08  4.505845e+08
# energy_waste           3.377330e+08  3.378418e+08  3.377330e+08  3.377331e+08
# nb_switches            0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# nb_computing_machines  1.600000e+01  1.600000e+01  1.600000e+01  1.600000e+01
# simulation_time        2.065587e+00  2.128419e+01  2.118910e+00  3.154052e+00

# %%
from analysis.visual import logs_to_jobset

jobsets = logs_to_jobset(BASE_DIR)
jobsets
# Out:
# {'EASY+DQN': <evalys.jobset.JobSet at 0x7f0ef1e5ea80>,
#  'EASY': <evalys.jobset.JobSet at 0x7f0f8529d910>,
#  'FCFS': <evalys.jobset.JobSet at 0x7f0f8529d9a0>,
#  'DQN': <evalys.jobset.JobSet at 0x7f0ef5056540>}

# %%
jobsets["DQN"].plot(with_details=True)
plt.show()
# Out:
# /home/jpbrione/.conda/envs/bati-env/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
jobsets["FCFS"].plot(with_details=True)
plt.show()
# Out:
# /home/jpbrione/.conda/envs/bati-env/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### old

# %%
sim_files  = BASE_DIR.glob("SimulationMonitor-*.out")
jobs_files = BASE_DIR.glob("JobMonitor-*.out")
schedule_files = BASE_DIR.glob("SchedulerMonitor-*.out")

# %%
metrics = pd.DataFrame()
for file in BASE_DIR.glob("SchedulerMonitor-*.out"):
    algorithm = re.search(r'SchedulerMonitor-(.*?)\.', str(file)).group(1)

    
    curr = pd.read_csv(str(file))
    curr["schedule"] = algorithm
    metrics = metrics.append(curr)

metrics.set_index('schedule', inplace=True)

# %%
from evalys.jobset import JobSet
jobsets = {}

for file in BASE_DIR.glob("JobMonitor-*.out"):
    algorithm = re.search(r'JobMonitor-(.*?)\.', str(file)).group(1)
    jobsets[algorithm] = JobSet.from_csv(str(file))

# %%
def calculate_compute_utilisation(schedule):
    compute_time = jobsets[schedule].df[['execution_time', 'requested_number_of_resources']].apply(lambda row: row.execution_time * row.requested_number_of_resources, axis=1).sum()
    return compute_time / (metrics.loc[schedule].makespan * 96)

def bounded_slowdown(df):
    return (df.turnaround_time / df.execution_time.clip(lower=60)).clip(lower=1)

def create_metric_df(metric):
    return pd.concat([jobsets[schedule].df[metric].rename(schedule) for schedule in schedule_names], axis=1)
    
def create_all_metrics_df():
    dfs = []
    for schedule in schedule_names:
        df = jobsets[schedule].df
        df = df.assign(schedule=schedule).assign(bounded_slowdown=bounded_slowdown(df))[['schedule', 'waiting_time', 'turnaround_time', 'stretch']]
        dfs.append(df)
    df = pd.concat(dfs, axis=0).rename({'stretch': 'slowdown'}, axis=1)
    return df

# %%
metrics['compute_utilisation'] = pd.Series({schedule: calculate_compute_utilisation(schedule) for schedule in schedule_names})

metrics.T
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[243], line 1
# ----> 1 metrics['compute_utilisation'] = pd.Series({schedule: calculate_compute_utilisation(schedule) for schedule in schedule_names})
#       3 metrics.T
#
# Cell In[242], line 2, in calculate_compute_utilisation(schedule)
#       1 def calculate_compute_utilisation(schedule):
# ----> 2     compute_time = jobsets[schedule].df[['execution_time', 'requested_number_of_resources']].apply(lambda row: row.execution_time * row.requested_number_of_resources, axis=1).sum()
#       3     return compute_time / (metrics.loc[schedule].makespan * 96)
#
# KeyError: 'DQN'

# %% [markdown]
# # New

# %%
waiting_times = pd.concat([ j.df['waiting_time'].rename(i) for i, j in jobsets.items() if i != "FCFS"], axis=1)
waiting_times.describe()
# Out:
#            EASY+DQN          EASY           DQN
# count   2450.000000   2450.000000   2450.000000
# mean     664.397551    676.558776    590.231020
# std     1241.226003   1226.945631   1356.420936
# min        0.000000      0.000000      0.000000
# 25%       17.000000     17.000000     17.000000
# 50%      164.000000    178.000000    154.000000
# 75%      742.750000    797.750000    630.000000
# max    13317.000000  13320.000000  20286.000000

# %%
fig, ax = plt.subplots(figsize=(7.2,4))
sns.barplot(data=waiting_times, ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(20,8))

temp = jobsets
del temp["FCFS"]

evalys.visu.legacy.plot_series('waiting_time', temp)

# %% [markdown]
# # Energy

# %%
temp = df["SimulationMonitor"].reset_index()
#temp = temp[ temp["schedule"].isin(["FCFS", "1TEST"]) ]

# Slowdown
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.bar('schedule', 'mean_slowdown', data=temp, width=0.6)
plt.grid(axis='y')
plt.ylabel("Averaged Slowdown (s)")

# Energy consumed
plt.subplot(1, 2, 2)
plt.bar('schedule', 'consumed_joules', data=temp, width=0.6)
plt.grid(axis='y')
plt.ylabel("Energy Consumed (J)")

# Show
plt.show()

# %%
dqn  = df["HostStateSwitchMonitor"][ df["HostStateSwitchMonitor"].index == "EASY+DQN" ]

plt.figure(figsize=(14,4))

plt.subplot(2,1,1)
plt.hist('nb_idle', data=dqn)

plt.subplot(2,1,2)
plt.plot('time', 'nb_idle', data=dqn)
plt.ylim(0,16)
plt.show()

# %%
fcfs = df["HostStateSwitchMonitor"][ df["HostStateSwitchMonitor"].index == "FCFS" ]

plt.figure(figsize=(14,4))

plt.subplot(2,1,1)
plt.hist('nb_idle', data=fcfs)

plt.subplot(2,1,2)
plt.plot('time', 'nb_idle', data=fcfs)
plt.ylim(0,5)
plt.show()

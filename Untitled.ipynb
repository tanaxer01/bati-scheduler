# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Read results
fcfs, easy = pd.read_csv("expe-out/sim-FCFS.out"), pd.read_csv("expe-out/sim-EASY.out")
fcfs['name'], easy['name'] = "FCFS", "EASY"
benchmark = pd.concat([fcfs, easy], ignore_index=True)

# Waiting time
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.bar('name', 'mean_waiting_time', data=benchmark, width=0.6)
plt.grid(axis='y')
plt.ylabel("Averaged Waiting Time")

# Slowdown
plt.subplot(1, 2, 2)
plt.bar('name', 'mean_slowdown', data=benchmark, width=0.6)
plt.grid(axis='y')
plt.ylabel("Averaged Slowdown")

# Show
plt.show()

# %%
from evalys.jobset import JobSet
from evalys.visu.legacy import plot_gantt

# Convert monitors to dataframes
fcfs, easy = pd.read_csv("expe-out/jobs-FCFS.out"), pd.read_csv("expe-out/jobs-EASY.out")

a = JobSet(fcfs)
'''
# Load dataframes into JobSet objects.
fcfs, easy = JobSet(fcfs), JobSet(easy)

# Plot gantts
_, ax_list = plt.subplots(1, 2, sharey=True, figsize=(12, 4))
plot_gantt(fcfs, ax=ax_list[0], title="FCFS Scheduler")
plot_gantt(easy, ax=ax_list[1], title="EASY Scheduler")

# Show
plt.ylim(ymin=0, ymax=2)
plt.yticks([0, 1, 2]) # We have two hosts only.
plt.show()
'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 7
#       4 # Convert monitors to dataframes
#       5 fcfs, easy = pd.read_csv("expe-out/jobs-FCFS.out"), pd.read_csv("expe-out/jobs-EASY.out")
# ----> 7 a = JobSet(fcfs)
#       8 '''
#       9 # Load dataframes into JobSet objects.
#      10 fcfs, easy = JobSet(fcfs), JobSet(easy)
#    (...)
#      20 plt.show()
#      21 '''
#
# File ~/work/memoria/new-bati/env/lib/python3.11/site-packages/evalys/jobset.py:65, in JobSet.__init__(self, df, resource_bounds, float_precision)
#      61             except ValueError:
#      62                 pass
#      64     self.res_bounds = ProcInt(
# ---> 65         min(alloc_apply(lambda pset: pset.min, self.df.allocated_resources)),
#      66         max(alloc_apply(lambda pset: pset.max, self.df.allocated_resources))
#      67     )
#      68 self.MaxProcs = len(self.res_bounds)
#      70 self.df['proc_alloc'] = self.df.allocated_resources.apply(len)
#
# File ~/work/memoria/new-bati/env/lib/python3.11/site-packages/evalys/jobset.py:60, in JobSet.__init__.<locals>.alloc_apply(f, alloc)
#      58 for pset in  alloc:
#      59     try:
# ---> 60         yield f(pset)
#      61     except ValueError:
#      62         pass
#
# File ~/work/memoria/new-bati/env/lib/python3.11/site-packages/evalys/jobset.py:65, in JobSet.__init__.<locals>.<lambda>(pset)
#      61             except ValueError:
#      62                 pass
#      64     self.res_bounds = ProcInt(
# ---> 65         min(alloc_apply(lambda pset: pset.min, self.df.allocated_resources)),
#      66         max(alloc_apply(lambda pset: pset.max, self.df.allocated_resources))
#      67     )
#      68 self.MaxProcs = len(self.res_bounds)
#      70 self.df['proc_alloc'] = self.df.allocated_resources.apply(len)
#
# AttributeError: 'str' object has no attribute 'min'

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

sim_f = pd.read_csv("expe-out/sim.out")
sim_f['name'] = "FirstFit"

plt.figure(figsize=(12,4))

# Waiting time
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.bar('name', 'mean_waiting_time', data=sim_f, width=0.6)
plt.grid(axis='y')
plt.ylabel("Averaged Waiting Time")

# Slowdown
plt.subplot(1, 2, 2)
plt.bar('name', 'mean_slowdown', data=sim_f, width=0.6)
plt.grid(axis='y')
plt.ylabel("Averaged Slowdown")
# Out:
# Text(0, 0.5, 'Averaged Slowdown')

# %%
from evalys.jobset import JobSet
from evalys.visu.legacy import plot_gantt

jobs_f = pd.read_csv("expe-out/jobs.out")
jobs_f = JobSet(jobs_f)

#plot_gantt(jobs_f, title="FFScheduler")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 5
#       2 from evalys.visu.legacy import plot_gantt
#       4 jobs_f = pd.read_csv("expe-out/jobs.out")
# ----> 5 jobs_f = JobSet(jobs_f)
#       7 #plot_gantt(jobs_f, title="FFScheduler")
#
# File ~/work/memoria/new-bati/env/lib/python3.11/site-packages/evalys/jobset.py:65, in JobSet.__init__(self, df, resource_bounds, float_precision)
#      61             except ValueError:
#      62                 pass
#      64     self.res_bounds = ProcInt(
# ---> 65         min(alloc_apply(lambda pset: pset.min, self.df.allocated_resources)),
#      66         max(alloc_apply(lambda pset: pset.max, self.df.allocated_resources))
#      67     )
#      68 self.MaxProcs = len(self.res_bounds)
#      70 self.df['proc_alloc'] = self.df.allocated_resources.apply(len)
#
# File ~/work/memoria/new-bati/env/lib/python3.11/site-packages/evalys/jobset.py:60, in JobSet.__init__.<locals>.alloc_apply(f, alloc)
#      58 for pset in  alloc:
#      59     try:
# ---> 60         yield f(pset)
#      61     except ValueError:
#      62         pass
#
# File ~/work/memoria/new-bati/env/lib/python3.11/site-packages/evalys/jobset.py:65, in JobSet.__init__.<locals>.<lambda>(pset)
#      61             except ValueError:
#      62                 pass
#      64     self.res_bounds = ProcInt(
# ---> 65         min(alloc_apply(lambda pset: pset.min, self.df.allocated_resources)),
#      66         max(alloc_apply(lambda pset: pset.max, self.df.allocated_resources))
#      67     )
#      68 self.MaxProcs = len(self.res_bounds)
#      70 self.df['proc_alloc'] = self.df.allocated_resources.apply(len)
#
# AttributeError: 'str' object has no attribute 'min'

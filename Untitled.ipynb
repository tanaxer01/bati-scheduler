# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re
import evalys

#schedule_names = ['FCFS', 'EASY', 'DQN']
schedule_names = ['FCFS', 'DQN']

pd.DataFrame.append = pd.DataFrame._append

BASE_DIR = Path("./expe-out/")

# %% [markdown]
# # Simulations

# %%
from analysis.visual import logs_to_df

file_types = [ 
    "SimulationMonitor",
#    "JobMonitor",
    "SchedulerMonitor",
    "ConsumedEnergyMonitor",
    "HostStateSwitchMonitor"
]

df = logs_to_df(BASE_DIR, file_types)

df["SchedulerMonitor"].sort_index().T
# Out:
# schedule                        DQN           DQN2           DQN3  \
# makespan              259388.000000  259388.000000  259399.000000
# max_slowdown            1309.000000    1309.000000    1312.000000
# max_stretch             2516.323398    2516.323398    2522.094782
# max_waiting_time        1308.000000    1308.000000    1311.000000
# max_turnaround_time     1996.000000    1996.000000    1999.000000
# mean_slowdown             22.759682      22.560176      22.949537
# mean_pp_slowdown          22.726083      22.526572      22.915332
# mean_stretch              16.732298      16.611849      16.878336
# mean_waiting_time        119.669796     119.691020     121.574694
# mean_turnaround_time     243.435918     243.528571     245.827755
# nb_jobs                 2450.000000    2450.000000    2450.000000
# nb_jobs_finished        2450.000000    2450.000000    2450.000000
# nb_jobs_killed           460.000000     467.000000     472.000000
# nb_jobs_rejected           0.000000       0.000000       0.000000
# nb_jobs_success         1990.000000    1983.000000    1978.000000
#
# schedule                       EASY       EASY+DQN           FCFS
# makespan              259389.000000  259400.000000  259389.000000
# max_slowdown            1309.000000    1311.000000    1309.000000
# max_stretch             2516.323398    2520.170987    2516.323398
# max_waiting_time        1308.000000    1310.000000    1308.000000
# max_turnaround_time     1996.000000    2002.000000    1996.000000
# mean_slowdown             21.362231      24.455857      21.375417
# mean_pp_slowdown          21.328633      24.420303      21.341810
# mean_stretch              18.231660      18.621075      18.240954
# mean_waiting_time        127.015102     131.120408     127.044082
# mean_turnaround_time     257.402449     261.579184     257.444898
# nb_jobs                 2450.000000    2450.000000    2450.000000
# nb_jobs_finished        2450.000000    2450.000000    2450.000000
# nb_jobs_killed          1245.000000    1234.000000    1249.000000
# nb_jobs_rejected           0.000000       0.000000       0.000000
# nb_jobs_success         1205.000000    1216.000000    1201.000000

# %%
df["SimulationMonitor"].T
# Out:
# schedule                       DQN2          EASY          DQN3      EASY+DQN  \
# makespan               2.593880e+05  2.593890e+05  2.602550e+05  2.594000e+05
# max_slowdown           1.309000e+03  1.309000e+03  1.481900e+04  1.311000e+03
# max_stretch            2.516323e+03  2.516323e+03  9.044536e+03  2.520171e+03
# max_waiting_time       1.308000e+03  1.308000e+03  1.541400e+04  1.310000e+03
# max_turnaround_time    1.996000e+03  1.996000e+03  1.594500e+04  2.002000e+03
# mean_slowdown          2.256018e+01  2.136223e+01  6.999622e+01  2.445586e+01
# mean_pp_slowdown       2.252657e+01  2.132863e+01  6.967598e+01  2.442030e+01
# mean_stretch           1.661185e+01  1.823166e+01  6.343054e+01  1.862108e+01
# mean_waiting_time      1.196910e+02  1.270151e+02  6.076967e+02  1.311204e+02
# mean_turnaround_time   2.435286e+02  2.574024e+02  7.410959e+02  2.615792e+02
# nb_jobs                2.450000e+03  2.450000e+03  2.450000e+03  2.450000e+03
# nb_jobs_finished       2.450000e+03  2.450000e+03  2.450000e+03  2.450000e+03
# nb_jobs_killed         4.670000e+02  1.245000e+03  4.010000e+02  1.234000e+03
# nb_jobs_rejected       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# nb_jobs_success        1.983000e+03  1.205000e+03  2.049000e+03  1.216000e+03
# time_idle              3.529389e+06  3.510022e+06  6.850000e+03  3.510738e+06
# time_computing         6.208190e+05  6.402020e+05  6.497310e+05  6.396620e+05
# time_switching_off     0.000000e+00  0.000000e+00  1.911000e+03  0.000000e+00
# time_switching_on      0.000000e+00  0.000000e+00  4.230000e+02  0.000000e+00
# time_sleeping          0.000000e+00  0.000000e+00  3.821050e+05  0.000000e+00
# consumed_joules        4.532476e+08  4.550905e+08  1.277845e+08  4.550559e+08
# energy_waste           3.352920e+08  3.334521e+08  8.966360e+05  3.335201e+08
# nb_switches            0.000000e+00  0.000000e+00  2.540000e+03  0.000000e+00
# nb_computing_machines  1.600000e+01  1.600000e+01  4.000000e+00  1.600000e+01
# simulation_time        3.337274e+00  2.128086e+00  4.681610e+00  2.296823e+01
#
# schedule                       FCFS           DQN
# makespan               2.593890e+05  2.593880e+05
# max_slowdown           1.309000e+03  1.309000e+03
# max_stretch            2.516323e+03  2.516323e+03
# max_waiting_time       1.308000e+03  1.308000e+03
# max_turnaround_time    1.996000e+03  1.996000e+03
# mean_slowdown          2.137542e+01  2.275968e+01
# mean_pp_slowdown       2.134181e+01  2.272608e+01
# mean_stretch           1.824095e+01  1.673230e+01
# mean_waiting_time      1.270441e+02  1.196698e+02
# mean_turnaround_time   2.574449e+02  2.434359e+02
# nb_jobs                2.450000e+03  2.450000e+03
# nb_jobs_finished       2.450000e+03  2.450000e+03
# nb_jobs_killed         1.249000e+03  4.600000e+02
# nb_jobs_rejected       0.000000e+00  0.000000e+00
# nb_jobs_success        1.201000e+03  1.990000e+03
# time_idle              3.509987e+06  3.529696e+06
# time_computing         6.402370e+05  6.205120e+05
# time_switching_off     0.000000e+00  0.000000e+00
# time_switching_on      0.000000e+00  0.000000e+00
# time_sleeping          0.000000e+00  0.000000e+00
# consumed_joules        4.550938e+08  4.532184e+08
# energy_waste           3.334488e+08  3.353211e+08
# nb_switches            0.000000e+00  0.000000e+00
# nb_computing_machines  1.600000e+01  1.600000e+01
# simulation_time        2.099373e+00  3.676968e+00

# %%
from analysis.visual import logs_to_jobset

jobsets = logs_to_jobset(BASE_DIR)
jobsets
# Out:
# {'DQN2': <evalys.jobset.JobSet at 0x7f0ee8ea1520>,
#  'EASY+DQN': <evalys.jobset.JobSet at 0x7f0ef1fef3e0>,
#  'EASY': <evalys.jobset.JobSet at 0x7f0ee994a750>,
#  'FCFS': <evalys.jobset.JobSet at 0x7f0eea2b7a40>,
#  'DQN': <evalys.jobset.JobSet at 0x7f0ef2d66150>,
#  'DQN3': <evalys.jobset.JobSet at 0x7f0f84ef7f80>}

# %%
jobsets["DQN"].plot(with_details=True)
plt.show()

# %%
jobsets["DQN3"].plot(with_details=True)
plt.show()

# %% [markdown]
# ### old

# %%
sim_files  = BASE_DIR.glob("SimulationMonitor-*.out")
jobs_files = BASE_DIR.glob("JobMonitor-*.out")
schedule_files = BASE_DIR.glob("SchedulerMonitor-*.out")

# %%
metrics = pd.DataFrame()
for file in BASE_DIR.glob("SchedulerMonitor-*.out"):
    algorithm = re.search(r'SchedulerMonitor-(.*?)\.', str(file)).group(1)

    
    curr = pd.read_csv(str(file))
    curr["schedule"] = algorithm
    metrics = metrics.append(curr)

metrics.set_index('schedule', inplace=True)

# %%
from evalys.jobset import JobSet
jobsets = {}

for file in BASE_DIR.glob("JobMonitor-*.out"):
    algorithm = re.search(r'JobMonitor-(.*?)\.', str(file)).group(1)
    jobsets[algorithm] = JobSet.from_csv(str(file))

# %%
def calculate_compute_utilisation(schedule):
    compute_time = jobsets[schedule].df[['execution_time', 'requested_number_of_resources']].apply(lambda row: row.execution_time * row.requested_number_of_resources, axis=1).sum()
    return compute_time / (metrics.loc[schedule].makespan * 96)

def bounded_slowdown(df):
    return (df.turnaround_time / df.execution_time.clip(lower=60)).clip(lower=1)

def create_metric_df(metric):
    return pd.concat([jobsets[schedule].df[metric].rename(schedule) for schedule in schedule_names], axis=1)
    
def create_all_metrics_df():
    dfs = []
    for schedule in schedule_names:
        df = jobsets[schedule].df
        df = df.assign(schedule=schedule).assign(bounded_slowdown=bounded_slowdown(df))[['schedule', 'waiting_time', 'turnaround_time', 'stretch']]
        dfs.append(df)
    df = pd.concat(dfs, axis=0).rename({'stretch': 'slowdown'}, axis=1)
    return df

# %%
metrics['compute_utilisation'] = pd.Series({schedule: calculate_compute_utilisation(schedule) for schedule in schedule_names})

metrics.T
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[243], line 1
# ----> 1 metrics['compute_utilisation'] = pd.Series({schedule: calculate_compute_utilisation(schedule) for schedule in schedule_names})
#       3 metrics.T
#
# Cell In[242], line 2, in calculate_compute_utilisation(schedule)
#       1 def calculate_compute_utilisation(schedule):
# ----> 2     compute_time = jobsets[schedule].df[['execution_time', 'requested_number_of_resources']].apply(lambda row: row.execution_time * row.requested_number_of_resources, axis=1).sum()
#       3     return compute_time / (metrics.loc[schedule].makespan * 96)
#
# KeyError: 'DQN'

# %% [markdown]
# # New

# %%
waiting_times = pd.concat([ j.df['waiting_time'].rename(i) for i, j in jobsets.items() ], axis=1)
waiting_times.describe()
# Out:
#               DQN2     EASY+DQN         EASY         FCFS          DQN  \
# count  2450.000000  2450.000000  2450.000000  2450.000000  2450.000000
# mean    119.691020   131.120408   127.015102   127.044082   119.669796
# std     228.126607   238.125591   237.622334   237.615024   227.912876
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000    10.000000     4.000000     4.000000     3.000000
# 50%      13.000000    20.000000    15.000000    15.000000    13.000000
# 75%      82.000000    95.000000    87.000000    87.000000    82.000000
# max    1308.000000  1310.000000  1308.000000  1308.000000  1308.000000
#
#               DQN3
# count  2450.000000
# mean    121.574694
# std     228.435241
# min       0.000000
# 25%       5.000000
# 50%      15.000000
# 75%      83.000000
# max    1311.000000

# %%
fig, ax = plt.subplots(figsize=(7.2,4))
sns.barplot(data=waiting_times, ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(20,8))

temp = jobsets
del temp["FCFS"]

evalys.visu.legacy.plot_series('waiting_time', temp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[249], line 4
#       1 fig, ax = plt.subplots(figsize=(20,8))
#       3 temp = jobsets
# ----> 4 del temp["FCFS"]
#       6 evalys.visu.legacy.plot_series('waiting_time', temp)
#
# KeyError: 'FCFS'

# %% [markdown]
# # Energy

# %%
temp = df["SimulationMonitor"].reset_index()
#temp = temp[ temp["schedule"].isin(["FCFS", "1TEST"]) ]

# Slowdown
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.bar('schedule', 'mean_slowdown', data=temp, width=0.6)
plt.grid(axis='y')
plt.ylabel("Averaged Slowdown (s)")

# Energy consumed
plt.subplot(1, 2, 2)
plt.bar('schedule', 'consumed_joules', data=temp, width=0.6)
plt.grid(axis='y')
plt.ylabel("Energy Consumed (J)")

# Show
plt.show()

# %%
dqn  = df["HostStateSwitchMonitor"][ df["HostStateSwitchMonitor"].index == "DQN3" ]

plt.figure(figsize=(14,4))

plt.subplot(2,1,1)
plt.hist('nb_idle', data=dqn)

plt.subplot(2,1,2)
plt.plot('time', 'nb_idle', data=dqn)
plt.ylim(0,16)
plt.show()

# %%
fcfs = df["HostStateSwitchMonitor"][ df["HostStateSwitchMonitor"].index == "EASY+DQN" ]

plt.figure(figsize=(14,4))

plt.subplot(2,1,1)
plt.hist('nb_idle', data=fcfs)

plt.subplot(2,1,2)
plt.plot('time', 'nb_idle', data=fcfs)
plt.ylim(0,16)
plt.show()

# %%
from evalys.mstates import MachineStatesChanges
from evalys.visu.legacy import plot_mstates

_, ax_list = plt.subplots(2, 1, sharex=True, sharey=False, figsize=(14, 8))

A = df["HostStateSwitchMonitor"][ df["HostStateSwitchMonitor"].index == "DQN3" ]
plot_mstates(A, ax=ax_list[0], title="Resources state: Without Shutdown Policy")
B = df["HostStateSwitchMonitor"][ df["HostStateSwitchMonitor"].index == "EASY+DQN" ]
plot_mstates(B,  ax=ax_list[1], title="Resources state: Timeout (1)")
ax_list[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Show
#plt.xlim(xmin=0, xmax=160)
plt.show()
A
# Out:
#             time  nb_sleeping  nb_switching_on  nb_switching_off  nb_idle  \
# schedule
# DQN3           0            0                0                 0        4
# DQN3          10            0                0                 4        0
# DQN3          13            4                0                 0        0
# DQN3         520            3                0                 0        0
# DQN3         530            0                3                 0        0
# ...          ...          ...              ...               ...      ...
# DQN3      259587            1                1                 0        2
# DQN3      259588            1                0                 0        0
# DQN3      260242            1                0                 0        3
# DQN3      260252            1                0                 3        0
# DQN3      260255            4                0                 0        0
#
#           nb_computing  nb_unavailable
# schedule
# DQN3                 0               0
# DQN3                 0               0
# DQN3                 0               0
# DQN3                 1               0
# DQN3                 1               0
# ...                ...             ...
# DQN3                 0               0
# DQN3                 3               0
# DQN3                 0               0
# DQN3                 0               0
# DQN3                 0               0
#
# [3933 rows x 7 columns]

# %%
def prepare(dataframe):
    df = dataframe[['time', 'energy']].drop_duplicates(subset='time')
    diff = df.diff(1)
    diff.rename(columns={'time':'time_diff', 'energy':'energy_diff'}, inplace=True)
    concat = pd.concat([df, diff], axis=1)
    concat['power'] = concat['energy_diff'] / concat['time_diff']
    return concat

# Plot
_, ax_list = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(14, 8))
ax_list[0].plot(none['time'], none['power'], drawstyle='steps-pre')
ax_list[0].set_title('Without Shutdown Policy')

ax_list[1].plot(t_1['time'], t_1['power'], label="Power (W)", drawstyle='steps-pre')
ax_list[1].set_title('Timeout (1)')
ax_list[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

#ax_list[2].plot(t_5['time'], t_5['power'], drawstyle='steps-pre')
#ax_list[2].set_title('Timeout (5)')


# Show
plt.xlim(xmin=0, xmax=160)
plt.ylim(ymin=0, ymax=400)
plt.show()

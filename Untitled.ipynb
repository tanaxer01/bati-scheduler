# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re
import evalys

#schedule_names = ['FCFS', 'EASY', 'DQN']
schedule_names = ['FCFS', 'DQN']

pd.DataFrame.append = pd.DataFrame._append

BASE_DIR = Path("./expe-out/")

# %% [markdown]
# # Simulations

# %%
from analysis.visual import logs_to_df

file_types = [ 
    "SimulationMonitor",
#    "JobMonitor",
    "SchedulerMonitor",
    "ConsumedEnergyMonitor",
    "HostStateSwitchMonitor"
]

df = logs_to_df(BASE_DIR, file_types)

df["SchedulerMonitor"].T
# Out:
# schedule                      2TEST           FCFS          1TEST  \
# makespan              260257.000000  260265.000000  260265.000000
# max_slowdown            6674.000000   11736.000000    9981.000000
# max_stretch            16428.812046   30424.716205   15600.019249
# max_waiting_time       19346.000000   12840.000000   21420.000000
# max_turnaround_time    19349.000000   12884.000000   21986.000000
# mean_slowdown            121.656286     144.707416     144.860012
# mean_pp_slowdown         121.317701     144.348484     144.488525
# mean_stretch             125.890513     140.971898     135.692214
# mean_waiting_time        903.944082     981.271429     986.000000
# mean_turnaround_time    1036.679592    1115.020408    1119.893469
# nb_jobs                 2450.000000    2450.000000    2450.000000
# nb_jobs_finished        2450.000000    2450.000000    2450.000000
# nb_jobs_killed           401.000000     401.000000     401.000000
# nb_jobs_rejected           0.000000       0.000000       0.000000
# nb_jobs_success         2049.000000    2049.000000    2049.000000
#
# schedule                      3TEST
# makespan              261010.000000
# max_slowdown           14716.000000
# max_stretch            33485.902502
# max_waiting_time       18685.000000
# max_turnaround_time    19172.000000
# mean_slowdown            169.259634
# mean_pp_slowdown         168.921244
# mean_stretch             141.344804
# mean_waiting_time        947.797959
# mean_turnaround_time    1079.215102
# nb_jobs                 2450.000000
# nb_jobs_finished        2450.000000
# nb_jobs_killed           401.000000
# nb_jobs_rejected           0.000000
# nb_jobs_success         2049.000000

# %%
df["SimulationMonitor"].T
# Out:
# schedule                    OLDFCFS         2TEST         3TEST          FCFS  \
# makespan               2.602490e+05  2.602570e+05  2.610100e+05  2.602650e+05
# max_slowdown           1.267100e+04  1.095900e+04  1.471600e+04  1.173600e+04
# max_stretch            3.066533e+04  2.801320e+04  3.348590e+04  3.042472e+04
# max_waiting_time       1.318300e+04  1.505500e+04  1.868500e+04  1.284000e+04
# max_turnaround_time    1.320500e+04  1.505800e+04  1.917200e+04  1.288400e+04
# mean_slowdown          1.544086e+02  1.405751e+02  1.692596e+02  1.447074e+02
# mean_pp_slowdown       1.540757e+02  1.402367e+02  1.689212e+02  1.443485e+02
# mean_stretch           1.276837e+02  1.357668e+02  1.413448e+02  1.409719e+02
# mean_waiting_time      9.128747e+02  9.550290e+02  9.477980e+02  9.812714e+02
# mean_turnaround_time   1.040902e+03  1.088667e+03  1.079215e+03  1.115020e+03
# nb_jobs                2.450000e+03  2.450000e+03  2.450000e+03  2.450000e+03
# nb_jobs_finished       2.450000e+03  2.450000e+03  2.450000e+03  2.450000e+03
# nb_jobs_killed         4.010000e+02  4.010000e+02  4.010000e+02  4.010000e+02
# nb_jobs_rejected       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# nb_jobs_success        2.049000e+03  2.049000e+03  2.049000e+03  2.049000e+03
# time_idle              4.044630e+05  3.907520e+05  3.994660e+05  3.907600e+05
# time_computing         6.365330e+05  6.502760e+05  6.445740e+05  6.503000e+05
# time_switching_off     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# time_switching_on      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# time_sleeping          0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# consumed_joules        1.593653e+08  1.606739e+08  1.604183e+08  1.606792e+08
# energy_waste           3.842398e+07  3.712144e+07  3.794927e+07  3.712220e+07
# nb_switches            0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# nb_computing_machines  4.000000e+00  4.000000e+00  4.000000e+00  4.000000e+00
# simulation_time        2.140361e+00  3.871284e+00  2.428821e+01  2.372431e+01
#
# schedule                      1TEST
# makespan               2.602650e+05
# max_slowdown           9.981000e+03
# max_stretch            1.560002e+04
# max_waiting_time       2.142000e+04
# max_turnaround_time    2.198600e+04
# mean_slowdown          1.448600e+02
# mean_pp_slowdown       1.444885e+02
# mean_stretch           1.356922e+02
# mean_waiting_time      9.860000e+02
# mean_turnaround_time   1.119893e+03
# nb_jobs                2.450000e+03
# nb_jobs_finished       2.450000e+03
# nb_jobs_killed         4.010000e+02
# nb_jobs_rejected       0.000000e+00
# nb_jobs_success        2.049000e+03
# time_idle              3.904030e+05
# time_computing         6.506570e+05
# time_switching_off     0.000000e+00
# time_switching_on      0.000000e+00
# time_sleeping          0.000000e+00
# consumed_joules        1.607131e+08
# energy_waste           3.708828e+07
# nb_switches            0.000000e+00
# nb_computing_machines  4.000000e+00
# simulation_time        2.503332e+01

# %%
from analysis.visual import logs_to_jobset

jobsets = logs_to_jobset(BASE_DIR)
jobsets
# Out:
# {'1TEST': <evalys.jobset.JobSet at 0x7f8b7942ed20>,
#  'OLDEASY': <evalys.jobset.JobSet at 0x7f8b85abb1d0>,
#  '2TEST': <evalys.jobset.JobSet at 0x7f8b85d8c200>,
#  'FCFS': <evalys.jobset.JobSet at 0x7f8b82fe9e80>,
#  'OLDFCFS': <evalys.jobset.JobSet at 0x7f8b7b2a9be0>,
#  '3TEST': <evalys.jobset.JobSet at 0x7f8b78a4b5f0>}

# %%
jobsets["FCFS"].plot(with_details=True)
plt.show()
# Out:
# /home/jpbrione/.conda/envs/bati-env/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
jobsets["OLDFCFS"].plot(with_details=True)
plt.show()
# Out:
# /home/jpbrione/.conda/envs/bati-env/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### old

# %%
sim_files  = BASE_DIR.glob("SimulationMonitor-*.out")
jobs_files = BASE_DIR.glob("JobMonitor-*.out")
schedule_files = BASE_DIR.glob("SchedulerMonitor-*.out")

# %%
metrics = pd.DataFrame()
for file in BASE_DIR.glob("SchedulerMonitor-*.out"):
    algorithm = re.search(r'SchedulerMonitor-(.*?)\.', str(file)).group(1)

    
    curr = pd.read_csv(str(file))
    curr["schedule"] = algorithm
    metrics = metrics.append(curr)

metrics.set_index('schedule', inplace=True)

# %%
from evalys.jobset import JobSet
jobsets = {}

for file in BASE_DIR.glob("JobMonitor-*.out"):
    algorithm = re.search(r'JobMonitor-(.*?)\.', str(file)).group(1)
    jobsets[algorithm] = JobSet.from_csv(str(file))

# %%
def calculate_compute_utilisation(schedule):
    compute_time = jobsets[schedule].df[['execution_time', 'requested_number_of_resources']].apply(lambda row: row.execution_time * row.requested_number_of_resources, axis=1).sum()
    return compute_time / (metrics.loc[schedule].makespan * 96)

def bounded_slowdown(df):
    return (df.turnaround_time / df.execution_time.clip(lower=60)).clip(lower=1)

def create_metric_df(metric):
    return pd.concat([jobsets[schedule].df[metric].rename(schedule) for schedule in schedule_names], axis=1)
    
def create_all_metrics_df():
    dfs = []
    for schedule in schedule_names:
        df = jobsets[schedule].df
        df = df.assign(schedule=schedule).assign(bounded_slowdown=bounded_slowdown(df))[['schedule', 'waiting_time', 'turnaround_time', 'stretch']]
        dfs.append(df)
    df = pd.concat(dfs, axis=0).rename({'stretch': 'slowdown'}, axis=1)
    return df

# %%
metrics['compute_utilisation'] = pd.Series({schedule: calculate_compute_utilisation(schedule) for schedule in schedule_names})

metrics.T
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[243], line 1
# ----> 1 metrics['compute_utilisation'] = pd.Series({schedule: calculate_compute_utilisation(schedule) for schedule in schedule_names})
#       3 metrics.T
#
# Cell In[242], line 2, in calculate_compute_utilisation(schedule)
#       1 def calculate_compute_utilisation(schedule):
# ----> 2     compute_time = jobsets[schedule].df[['execution_time', 'requested_number_of_resources']].apply(lambda row: row.execution_time * row.requested_number_of_resources, axis=1).sum()
#       3     return compute_time / (metrics.loc[schedule].makespan * 96)
#
# KeyError: 'DQN'

# %% [markdown]
# # New

# %%
waiting_times = pd.concat([ j.df['waiting_time'].rename(i) for i, j in jobsets.items() ], axis=1)
waiting_times.describe()
# Out:
#              1TEST      OLDEASY         2TEST          FCFS      OLDFCFS  \
# count   2450.00000  2450.000000   2450.000000   2450.000000  2450.000000
# mean     986.00000   422.323673    913.600000    981.271429  1660.416327
# std     2128.21474   892.834729   1764.341456   1717.017961  1927.555818
# min        0.00000     0.000000      0.000000      0.000000     0.000000
# 25%       35.00000     6.000000     40.000000     45.000000   108.250000
# 50%      290.00000    77.000000    330.000000    375.000000  1117.500000
# 75%      985.00000   480.750000   1070.000000   1085.000000  2237.000000
# max    21420.00000  8101.000000  19295.000000  12840.000000  8911.000000
#
#               3TEST
# count   2450.000000
# mean     947.797959
# std     1759.435915
# min        0.000000
# 25%       40.000000
# 50%      325.000000
# 75%     1105.000000
# max    18685.000000

# %%
fig, ax = plt.subplots(figsize=(7.2,4))
sns.barplot(data=waiting_times, ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(20,8))
evalys.visu.legacy.plot_series('waiting_time', jobsets)

# %% [markdown]
# # Energy

# %%
temp = df["SimulationMonitor"].reset_index()

# Slowdown
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.bar('schedule', 'mean_slowdown', data=temp, width=0.6)
plt.grid(axis='y')
plt.ylabel("Averaged Slowdown (s)")

# Energy consumed
plt.subplot(1, 2, 2)
plt.bar('schedule', 'consumed_joules', data=temp, width=0.6)
plt.grid(axis='y')
plt.ylabel("Energy Consumed (J)")

# Show
plt.show()

# %%
dqn  = df["HostStateSwitchMonitor"][ df["HostStateSwitchMonitor"].index == "2TEST" ]
dqn2 = df["HostStateSwitchMonitor"][ (df["HostStateSwitchMonitor"].index == "2TEST")]

cero = dqn[ dqn.nb_idle == 0 ].shape[0]
tres = dqn[ dqn.nb_idle <= 3 ].shape[0]
cinco = dqn[ dqn.nb_idle <= 5 ].shape[0]
total = dqn.shape[0]

print(cero, tres, cinco)
print(cero/total, tres/total, cinco/total)

plt.show()

fcfs = df["HostStateSwitchMonitor"][ (df["HostStateSwitchMonitor"].index == "FCFS") & ( df["HostStateSwitchMonitor"]["nb_idle"] > 0) ]

plt.figure(figsize=(14,4))

plt.subplot(2,1,1)
plt.hist('nb_idle', data=fcfs)

plt.subplot(2,1,2)
plt.plot('time', 'nb_idle', data=fcfs)
plt.ylim(0,5)
plt.show()
# Out:
# 1281 4017 4440
# 0.2885135135135135 0.9047297297297298 1.0
